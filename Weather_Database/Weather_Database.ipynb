# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 723

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests
# Import the time library
import time
# Import the API key.
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval")
print("----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})
        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | rawson
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | chinsali
# Processing Record 5 of Set 1 | muros
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | tateyama
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | narsaq
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 1 | olafsvik
# Processing Record 18 of Set 1 | severo-kurilsk
# Processing Record 19 of Set 1 | soligalich
# Processing Record 20 of Set 1 | baiyin
# Processing Record 21 of Set 1 | oranjestad
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | fukue
# Processing Record 26 of Set 1 | kavieng
# Processing Record 27 of Set 1 | nacala
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | mutsamudu
# City not found. Skipping...
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | dicabisagan
# Processing Record 32 of Set 1 | tsienyane
# City not found. Skipping...
# Processing Record 33 of Set 1 | asau
# Processing Record 34 of Set 1 | iesolo
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | hobart
# Processing Record 37 of Set 1 | seoul
# Processing Record 38 of Set 1 | burnie
# Processing Record 39 of Set 1 | chuy
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | sao filipe
# Processing Record 42 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 1 | klaksvik
# Processing Record 45 of Set 1 | castro
# Processing Record 46 of Set 1 | los llanos de aridane
# Processing Record 47 of Set 1 | upernavik
# Processing Record 48 of Set 1 | svetlaya
# Processing Record 49 of Set 1 | dekoa
# City not found. Skipping...
# Processing Record 50 of Set 1 | koslan
# Processing Record 1 of Set 2 | grand gaube
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | saint-philippe
# Processing Record 4 of Set 2 | pisco
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | planeta rica
# Processing Record 7 of Set 2 | rezh
# Processing Record 8 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 2 | berezniki
# Processing Record 10 of Set 2 | linxia
# Processing Record 11 of Set 2 | waingapu
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | rikitea
# Processing Record 14 of Set 2 | hainburg
# Processing Record 15 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 2 | katsuura
# Processing Record 17 of Set 2 | barrow
# Processing Record 18 of Set 2 | bryan
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | rocha
# Processing Record 21 of Set 2 | husavik
# Processing Record 22 of Set 2 | alto araguaia
# Processing Record 23 of Set 2 | smithers
# Processing Record 24 of Set 2 | san andres
# Processing Record 25 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 26 of Set 2 | chumikan
# Processing Record 27 of Set 2 | bathsheba
# Processing Record 28 of Set 2 | oistins
# Processing Record 29 of Set 2 | vila velha
# Processing Record 30 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 31 of Set 2 | luderitz
# Processing Record 32 of Set 2 | kaitangata
# Processing Record 33 of Set 2 | ha giang
# Processing Record 34 of Set 2 | henties bay
# Processing Record 35 of Set 2 | victoria
# Processing Record 36 of Set 2 | bar harbor
# Processing Record 37 of Set 2 | carnarvon
# Processing Record 38 of Set 2 | vanimo
# Processing Record 39 of Set 2 | kiama
# Processing Record 40 of Set 2 | clarence town
# Processing Record 41 of Set 2 | cabo san lucas
# Processing Record 42 of Set 2 | tuktoyaktuk
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | the pas
# Processing Record 45 of Set 2 | jerome
# Processing Record 46 of Set 2 | borkenes
# Processing Record 47 of Set 2 | srednekolymsk
# Processing Record 48 of Set 2 | butaritari
# Processing Record 49 of Set 2 | bilma
# Processing Record 50 of Set 2 | kodiak
# Processing Record 1 of Set 3 | cabedelo
# Processing Record 2 of Set 3 | hobyo
# Processing Record 3 of Set 3 | cherskiy
# Processing Record 4 of Set 3 | khatanga
# Processing Record 5 of Set 3 | rapid city
# Processing Record 6 of Set 3 | paamiut
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | mataura
# Processing Record 9 of Set 3 | dunedin
# Processing Record 10 of Set 3 | ugoofaaru
# Processing Record 11 of Set 3 | ola
# Processing Record 12 of Set 3 | bambous virieux
# Processing Record 13 of Set 3 | bratsk
# Processing Record 14 of Set 3 | verkhoturye
# City not found. Skipping...
# Processing Record 15 of Set 3 | chokurdakh
# City not found. Skipping...
# Processing Record 16 of Set 3 | busselton
# City not found. Skipping...
# Processing Record 17 of Set 3 | longyearbyen
# City not found. Skipping...
# Processing Record 18 of Set 3 | aykhal
# City not found. Skipping...
# Processing Record 19 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 3 | inverell
# City not found. Skipping...
# Processing Record 21 of Set 3 | harper
# City not found. Skipping...
# Processing Record 22 of Set 3 | whakatane
# City not found. Skipping...
# Processing Record 23 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 24 of Set 3 | gat
# City not found. Skipping...
# Processing Record 25 of Set 3 | meybod
# City not found. Skipping...
# Processing Record 26 of Set 3 | portland
# City not found. Skipping...
# Processing Record 27 of Set 3 | albany
# City not found. Skipping...
# Processing Record 28 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 3 | coquimbo
# City not found. Skipping...
# Processing Record 30 of Set 3 | saldanha
# City not found. Skipping...
# Processing Record 31 of Set 3 | dikson
# City not found. Skipping...
# Processing Record 32 of Set 3 | grindavik
# City not found. Skipping...
# Processing Record 33 of Set 3 | kaoma
# City not found. Skipping...
# Processing Record 34 of Set 3 | bengkulu
# City not found. Skipping...
# Processing Record 35 of Set 3 | cayenne
# City not found. Skipping...
# Processing Record 36 of Set 3 | flinders
# City not found. Skipping...
# Processing Record 37 of Set 3 | leningradskiy
# City not found. Skipping...
# Processing Record 38 of Set 3 | richards bay
# City not found. Skipping...
# Processing Record 39 of Set 3 | lasa
# City not found. Skipping...
# Processing Record 40 of Set 3 | abatskoye
# City not found. Skipping...
# Processing Record 41 of Set 3 | new norfolk
# City not found. Skipping...
# Processing Record 42 of Set 3 | atuona
# City not found. Skipping...
# Processing Record 43 of Set 3 | ilulissat
# City not found. Skipping...
# Processing Record 44 of Set 3 | shache
# City not found. Skipping...
# Processing Record 45 of Set 3 | simao
# City not found. Skipping...
# Processing Record 46 of Set 3 | esperance
# City not found. Skipping...
# Processing Record 47 of Set 3 | hede
# City not found. Skipping...
# Processing Record 48 of Set 3 | bac lieu
# City not found. Skipping...
# Processing Record 49 of Set 3 | sapouy
# City not found. Skipping...
# Processing Record 50 of Set 3 | havelock
# City not found. Skipping...
# Processing Record 1 of Set 4 | thisted
# Processing Record 2 of Set 4 | marzuq
# Processing Record 3 of Set 4 | maarianhamina
# Processing Record 4 of Set 4 | mitu
# Processing Record 5 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 4 | san quintin
# Processing Record 7 of Set 4 | isangel
# Processing Record 8 of Set 4 | auki
# Processing Record 9 of Set 4 | santa rosa
# Processing Record 10 of Set 4 | guicheng
# City not found. Skipping...
# Processing Record 11 of Set 4 | thunder bay
# Processing Record 12 of Set 4 | champasak
# Processing Record 13 of Set 4 | kruisfontein
# Processing Record 14 of Set 4 | sao domingos
# Processing Record 15 of Set 4 | mount isa
# Processing Record 16 of Set 4 | iqaluit
# Processing Record 17 of Set 4 | seymchan
# Processing Record 18 of Set 4 | methoni
# Processing Record 19 of Set 4 | mayskiy
# Processing Record 20 of Set 4 | namibe
# Processing Record 21 of Set 4 | daru
# Processing Record 22 of Set 4 | dalbandin
# Processing Record 23 of Set 4 | hami
# Processing Record 24 of Set 4 | codrington
# Processing Record 25 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 4 | khammam
# Processing Record 27 of Set 4 | nikolskoye
# Processing Record 28 of Set 4 | tiksi
# Processing Record 29 of Set 4 | nantucket
# Processing Record 30 of Set 4 | tikrit
# Processing Record 31 of Set 4 | nhulunbuy
# Processing Record 32 of Set 4 | east london
# Processing Record 33 of Set 4 | micheweni
# Processing Record 34 of Set 4 | ludvika
# Processing Record 35 of Set 4 | ixtapa
# Processing Record 36 of Set 4 | provideniya
# Processing Record 37 of Set 4 | najran
# Processing Record 38 of Set 4 | saskylakh
# Processing Record 39 of Set 4 | sorland
# Processing Record 40 of Set 4 | bilibino
# Processing Record 41 of Set 4 | lakefield
# Processing Record 42 of Set 4 | lazaro cardenas
# Processing Record 43 of Set 4 | merauke
# Processing Record 44 of Set 4 | dakar
# Processing Record 45 of Set 4 | port lincoln
# Processing Record 46 of Set 4 | muchkapskiy
# Processing Record 47 of Set 4 | hofn
# Processing Record 48 of Set 4 | bereda
# Processing Record 49 of Set 4 | goundam
# Processing Record 50 of Set 4 | turinsk
# Processing Record 1 of Set 5 | sogdiondon
# City not found. Skipping...
# Processing Record 2 of Set 5 | gudiyattam
# City not found. Skipping...
# Processing Record 3 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 5 | avera
# Processing Record 5 of Set 5 | bethel
# Processing Record 6 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 5 | arraial do cabo
# Processing Record 8 of Set 5 | guarapari
# Processing Record 9 of Set 5 | kayes
# Processing Record 10 of Set 5 | dzhebariki-khaya
# Processing Record 11 of Set 5 | lompoc
# Processing Record 12 of Set 5 | takoradi
# Processing Record 13 of Set 5 | ponta do sol
# Processing Record 14 of Set 5 | ancud
# Processing Record 15 of Set 5 | kuryk
# Processing Record 16 of Set 5 | faya
# Processing Record 17 of Set 5 | banda aceh
# Processing Record 18 of Set 5 | svetlogorsk
# Processing Record 19 of Set 5 | airai
# Processing Record 20 of Set 5 | stornoway
# Processing Record 21 of Set 5 | kracheh
# City not found. Skipping...
# Processing Record 22 of Set 5 | aswan
# Processing Record 23 of Set 5 | matadi
# Processing Record 24 of Set 5 | tasiilaq
# Processing Record 25 of Set 5 | te anau
# Processing Record 26 of Set 5 | kusk
# City not found. Skipping...
# Processing Record 27 of Set 5 | puerto narino
# Processing Record 28 of Set 5 | hatillo
# Processing Record 29 of Set 5 | sinjar
# Processing Record 30 of Set 5 | marivan
# Processing Record 31 of Set 5 | oussouye
# Processing Record 32 of Set 5 | vryburg
# Processing Record 33 of Set 5 | drumheller
# Processing Record 34 of Set 5 | ornskoldsvik
# Processing Record 35 of Set 5 | raudeberg
# Processing Record 36 of Set 5 | bandarbeyla
# Processing Record 37 of Set 5 | solnechnyy
# Processing Record 38 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 5 | tuatapere
# Processing Record 40 of Set 5 | hare bay
# Processing Record 41 of Set 5 | torbay
# Processing Record 42 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 43 of Set 5 | ponca city
# Processing Record 44 of Set 5 | sayyan
# Processing Record 45 of Set 5 | waddan
# Processing Record 46 of Set 5 | chunskiy
# Processing Record 47 of Set 5 | adrian
# Processing Record 48 of Set 5 | rome
# Processing Record 49 of Set 5 | tianmen
# Processing Record 50 of Set 5 | praia da vitoria
# Processing Record 1 of Set 6 | arona
# Processing Record 2 of Set 6 | chapeco
# Processing Record 3 of Set 6 | ambilobe
# Processing Record 4 of Set 6 | taltal
# Processing Record 5 of Set 6 | lorengau
# Processing Record 6 of Set 6 | cremona
# Processing Record 7 of Set 6 | sao joao da barra
# Processing Record 8 of Set 6 | vorukh
# Processing Record 9 of Set 6 | san roque
# Processing Record 10 of Set 6 | san policarpo
# Processing Record 11 of Set 6 | truro
# Processing Record 12 of Set 6 | marawi
# Processing Record 13 of Set 6 | beringovskiy
# Processing Record 14 of Set 6 | galle
# Processing Record 15 of Set 6 | bosaso
# Processing Record 16 of Set 6 | genhe
# Processing Record 17 of Set 6 | petrozavodsk
# Processing Record 18 of Set 6 | lebu
# Processing Record 19 of Set 6 | kiunga
# Processing Record 20 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 6 | korem
# Processing Record 22 of Set 6 | port augusta
# Processing Record 23 of Set 6 | alekseyevka
# Processing Record 24 of Set 6 | mareeba
# Processing Record 25 of Set 6 | hasaki
# Processing Record 26 of Set 6 | eregli
# Processing Record 27 of Set 6 | naryan-mar
# Processing Record 28 of Set 6 | ozu
# Processing Record 29 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 6 | starodub
# Processing Record 31 of Set 6 | pimentel
# Processing Record 32 of Set 6 | souillac
# Processing Record 33 of Set 6 | bambanglipuro
# Processing Record 34 of Set 6 | portel
# Processing Record 35 of Set 6 | bontang
# Processing Record 36 of Set 6 | port moresby
# Processing Record 37 of Set 6 | sibenik
# Processing Record 38 of Set 6 | pevek
# Processing Record 39 of Set 6 | mezen
# Processing Record 40 of Set 6 | kuala terengganu
# Processing Record 41 of Set 6 | laguna
# Processing Record 42 of Set 6 | lewisporte
# Processing Record 43 of Set 6 | boshnyakovo
# Processing Record 44 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 45 of Set 6 | benguela
# Processing Record 46 of Set 6 | lavrentiya
# Processing Record 47 of Set 6 | panzhihua
# Processing Record 48 of Set 6 | korla
# Processing Record 49 of Set 6 | elko
# Processing Record 50 of Set 6 | nicoya
# Processing Record 1 of Set 7 | cozumel
# Processing Record 2 of Set 7 | beira
# Processing Record 3 of Set 7 | port blair
# Processing Record 4 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 7 | gigmoto
# Processing Record 6 of Set 7 | otjimbingwe
# Processing Record 7 of Set 7 | chibombo
# Processing Record 8 of Set 7 | katangli
# Processing Record 9 of Set 7 | ostrovnoy
# Processing Record 10 of Set 7 | touros
# Processing Record 11 of Set 7 | ozernovskiy
# Processing Record 12 of Set 7 | faro
# Processing Record 13 of Set 7 | shimoda
# Processing Record 14 of Set 7 | port-gentil
# Processing Record 15 of Set 7 | caravelas
# Processing Record 16 of Set 7 | shubarkuduk
# Processing Record 17 of Set 7 | roros
# Processing Record 18 of Set 7 | pathankot
# Processing Record 19 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 7 | pangnirtung
# Processing Record 21 of Set 7 | sitka
# Processing Record 22 of Set 7 | winnemucca
# Processing Record 23 of Set 7 | prince rupert
# Processing Record 24 of Set 7 | misratah
# Processing Record 25 of Set 7 | huarmey
# Processing Record 26 of Set 7 | terrace
# Processing Record 27 of Set 7 | konza
# Processing Record 28 of Set 7 | sulangan
# Processing Record 29 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 7 | long
# Processing Record 31 of Set 7 | ust-barguzin
# Processing Record 32 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 7 | whitehorse
# Processing Record 34 of Set 7 | fortuna
# Processing Record 35 of Set 7 | markala
# Processing Record 36 of Set 7 | naze
# Processing Record 37 of Set 7 | magallanes
# Processing Record 38 of Set 7 | sungaipenuh
# Processing Record 39 of Set 7 | port elizabeth
# Processing Record 40 of Set 7 | roblin
# Processing Record 41 of Set 7 | deputatskiy
# Processing Record 42 of Set 7 | yara
# Processing Record 43 of Set 7 | kavaratti
# Processing Record 44 of Set 7 | norilsk
# Processing Record 45 of Set 7 | mattru
# Processing Record 46 of Set 7 | elizabeth city
# Processing Record 47 of Set 7 | buala
# Processing Record 48 of Set 7 | geraldton
# Processing Record 49 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 7 | kahului
# Processing Record 1 of Set 8 | lata
# Processing Record 2 of Set 8 | san cristobal
# Processing Record 3 of Set 8 | yerbogachen
# Processing Record 4 of Set 8 | pontianak
# Processing Record 5 of Set 8 | birjand
# Processing Record 6 of Set 8 | wollongong
# Processing Record 7 of Set 8 | shiyan
# Processing Record 8 of Set 8 | monte carmelo
# Processing Record 9 of Set 8 | leeton
# Processing Record 10 of Set 8 | ayia galini
# Processing Record 11 of Set 8 | acarau
# Processing Record 12 of Set 8 | igarka
# Processing Record 13 of Set 8 | yalchiki
# City not found. Skipping...
# Processing Record 14 of Set 8 | vieste
# Processing Record 15 of Set 8 | bundibugyo
# Processing Record 16 of Set 8 | domoni
# Processing Record 17 of Set 8 | gusau
# Processing Record 18 of Set 8 | weilmunster
# Processing Record 19 of Set 8 | whitefish
# Processing Record 20 of Set 8 | westport
# Processing Record 21 of Set 8 | santa cruz
# Processing Record 22 of Set 8 | socorro
# Processing Record 23 of Set 8 | muisne
# Processing Record 24 of Set 8 | bestobe
# Processing Record 25 of Set 8 | boddam
# Processing Record 26 of Set 8 | lagoa
# Processing Record 27 of Set 8 | dunmore east
# Processing Record 28 of Set 8 | fort nelson
# Processing Record 29 of Set 8 | praia
# Processing Record 30 of Set 8 | half moon bay
# Processing Record 31 of Set 8 | gemena
# Processing Record 32 of Set 8 | kupang
# Processing Record 33 of Set 8 | beloha
# Processing Record 34 of Set 8 | dunda
# Processing Record 35 of Set 8 | samarai
# Processing Record 36 of Set 8 | mongu
# Processing Record 37 of Set 8 | novaya ladoga
# Processing Record 38 of Set 8 | college
# Processing Record 39 of Set 8 | dali
# Processing Record 40 of Set 8 | winnipeg
# Processing Record 41 of Set 8 | hambantota
# Processing Record 42 of Set 8 | umm lajj
# Processing Record 43 of Set 8 | kirsanov
# Processing Record 44 of Set 8 | kandi
# Processing Record 45 of Set 8 | akyab
# Processing Record 46 of Set 8 | sangar
# Processing Record 47 of Set 8 | cuamba
# Processing Record 48 of Set 8 | thomaston
# Processing Record 49 of Set 8 | birin
# Processing Record 50 of Set 8 | saint-francois
# Processing Record 1 of Set 9 | tual
# Processing Record 2 of Set 9 | zhigansk
# Processing Record 3 of Set 9 | kimbe
# Processing Record 4 of Set 9 | viedma
# Processing Record 5 of Set 9 | alta
# Processing Record 6 of Set 9 | totolapan
# Processing Record 7 of Set 9 | dehloran
# Processing Record 8 of Set 9 | altay
# Processing Record 9 of Set 9 | faanui
# Processing Record 10 of Set 9 | kabalo
# Processing Record 11 of Set 9 | sechura
# Processing Record 12 of Set 9 | morros
# Processing Record 13 of Set 9 | hualmay
# Processing Record 14 of Set 9 | veydelevka
# Processing Record 15 of Set 9 | puerto del rosario
# Processing Record 16 of Set 9 | acapulco
# Processing Record 17 of Set 9 | jiuquan
# Processing Record 18 of Set 9 | lima
# Processing Record 19 of Set 9 | tukan
# Processing Record 20 of Set 9 | udachnyy
# Processing Record 21 of Set 9 | mao
# Processing Record 22 of Set 9 | hamilton
# Processing Record 23 of Set 9 | bardiyah
# Processing Record 24 of Set 9 | kavarna
# Processing Record 25 of Set 9 | rosarito
# Processing Record 26 of Set 9 | necochea
# Processing Record 27 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 9 | kailua
# Processing Record 29 of Set 9 | komsomolskiy
# Processing Record 30 of Set 9 | san jose
# Processing Record 31 of Set 9 | sindor
# Processing Record 32 of Set 9 | vammala
# Processing Record 33 of Set 9 | atar
# Processing Record 34 of Set 9 | vao
# Processing Record 35 of Set 9 | baruun-urt
# Processing Record 36 of Set 9 | dire dawa
# Processing Record 37 of Set 9 | san nicolas
# Processing Record 38 of Set 9 | north bend
# Processing Record 39 of Set 9 | healesville
# Processing Record 40 of Set 9 | baft
# Processing Record 41 of Set 9 | south daytona
# Processing Record 42 of Set 9 | pochutla
# Processing Record 43 of Set 9 | mogadishu
# Processing Record 44 of Set 9 | tiznit
# Processing Record 45 of Set 9 | nagayo
# Processing Record 46 of Set 9 | broken hill
# Processing Record 47 of Set 9 | peterhead
# Processing Record 48 of Set 9 | kirakira
# Processing Record 49 of Set 9 | mehamn
# Processing Record 50 of Set 9 | beldanga
# Processing Record 1 of Set 10 | ojinaga
# Processing Record 2 of Set 10 | sangmelima
# Processing Record 3 of Set 10 | tyukalinsk
# Processing Record 4 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 10 | chicama
# Processing Record 6 of Set 10 | brownsville
# Processing Record 7 of Set 10 | teya
# Processing Record 8 of Set 10 | oranjemund
# Processing Record 9 of Set 10 | zachary
# Processing Record 10 of Set 10 | san patricio
# Processing Record 11 of Set 10 | kanor
# Processing Record 12 of Set 10 | jahrom
# City not found. Skipping...
# Processing Record 13 of Set 10 | salamiyah
# Processing Record 14 of Set 10 | dabola
# Processing Record 15 of Set 10 | palitana
# Processing Record 16 of Set 10 | mwinilunga
# Processing Record 17 of Set 10 | cidreira
# Processing Record 18 of Set 10 | inhambane
# Processing Record 19 of Set 10 | ansbach
# Processing Record 20 of Set 10 | atbasar
# Processing Record 21 of Set 10 | kilindoni
# Processing Record 22 of Set 10 | orizona
# Processing Record 23 of Set 10 | ekhabi
# Processing Record 24 of Set 10 | bonanza
# Processing Record 25 of Set 10 | semporna
# Processing Record 26 of Set 10 | roma
# Processing Record 27 of Set 10 | sabang
# Processing Record 28 of Set 10 | angoche
# Processing Record 29 of Set 10 | rawlins
# Processing Record 30 of Set 10 | onega
# Processing Record 31 of Set 10 | makushino
# Processing Record 32 of Set 10 | arlit
# Processing Record 33 of Set 10 | port hawkesbury
# Processing Record 34 of Set 10 | kabanjahe
# Processing Record 35 of Set 10 | halifax
# Processing Record 36 of Set 10 | mizdah
# Processing Record 37 of Set 10 | bezhetsk
# Processing Record 38 of Set 10 | mount gambier
# Processing Record 39 of Set 10 | bowen
# Processing Record 40 of Set 10 | yulara
# Processing Record 41 of Set 10 | saint george
# Processing Record 42 of Set 10 | adrar
# Processing Record 43 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 10 | miraflores
# Processing Record 45 of Set 10 | dinar
# Processing Record 46 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 48 of Set 10 | nome
# Processing Record 49 of Set 10 | jerantut
# Processing Record 50 of Set 10 | kudahuvadhoo
# Processing Record 1 of Set 11 | tobol
# Processing Record 2 of Set 11 | ulladulla
# Processing Record 3 of Set 11 | awbari
# Processing Record 4 of Set 11 | waghai
# Processing Record 5 of Set 11 | ahipara
# Processing Record 6 of Set 11 | itarema
# Processing Record 7 of Set 11 | escanaba
# Processing Record 8 of Set 11 | evensk
# Processing Record 9 of Set 11 | matara
# Processing Record 10 of Set 11 | pleasanton
# Processing Record 11 of Set 11 | taoudenni
# Processing Record 12 of Set 11 | mana
# Processing Record 13 of Set 11 | plavinas
# Processing Record 14 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 11 | cojumatlan
# City not found. Skipping...
# Processing Record 16 of Set 11 | eureka
# Processing Record 17 of Set 11 | humaita
# Processing Record 18 of Set 11 | vestmannaeyjar
# Processing Record 19 of Set 11 | neiafu
# Processing Record 20 of Set 11 | alpinopolis
# Processing Record 21 of Set 11 | rosetta
# Processing Record 22 of Set 11 | rakaia
# Processing Record 23 of Set 11 | wangqing
# Processing Record 24 of Set 11 | qasigiannguit
# Processing Record 25 of Set 11 | willowmore
# Processing Record 26 of Set 11 | sorong
# Processing Record 27 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 28 of Set 11 | general roca
# Processing Record 29 of Set 11 | meulaboh
# Processing Record 30 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 11 | iskateley
# Processing Record 32 of Set 11 | sorkjosen
# Processing Record 33 of Set 11 | gomel
# Processing Record 34 of Set 11 | grenfell
# Processing Record 35 of Set 11 | xinan
# Processing Record 36 of Set 11 | torrevieja
# Processing Record 37 of Set 11 | union
# Processing Record 38 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 11 | lodwar
# Processing Record 40 of Set 11 | kodinsk
# Processing Record 41 of Set 11 | petropavlovka
# Processing Record 42 of Set 11 | palana
# Processing Record 43 of Set 11 | tessalit
# Processing Record 44 of Set 11 | poum
# Processing Record 45 of Set 11 | normandin
# Processing Record 46 of Set 11 | camacari
# Processing Record 47 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 11 | saint-pierre
# Processing Record 49 of Set 11 | macklin
# Processing Record 50 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 12 | scarborough
# Processing Record 2 of Set 12 | ridgecrest
# Processing Record 3 of Set 12 | port-cartier
# Processing Record 4 of Set 12 | moiyabana
# City not found. Skipping...
# Processing Record 5 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 7 of Set 12 | opuwo
# Processing Record 8 of Set 12 | montrose
# Processing Record 9 of Set 12 | naberera
# Processing Record 10 of Set 12 | waitati
# Processing Record 11 of Set 12 | juneau
# Processing Record 12 of Set 12 | labuhan
# Processing Record 13 of Set 12 | gwanda
# Processing Record 14 of Set 12 | saint-joseph
# Processing Record 15 of Set 12 | yanam
# Processing Record 16 of Set 12 | kisangani
# Processing Record 17 of Set 12 | milkovo
# Processing Record 18 of Set 12 | haines junction
# Processing Record 19 of Set 12 | barbacena
# Processing Record 20 of Set 12 | azangaro
# Processing Record 21 of Set 12 | asaba
# Processing Record 22 of Set 12 | dovolnoye
# Processing Record 23 of Set 12 | horki
# Processing Record 24 of Set 12 | clinton
# Processing Record 25 of Set 12 | the valley
# Processing Record 26 of Set 12 | talnakh
# Processing Record 27 of Set 12 | kieta
# Processing Record 28 of Set 12 | san carlos de bariloche
# Processing Record 29 of Set 12 | kamensk-shakhtinskiy
# Processing Record 30 of Set 12 | norman wells
# Processing Record 31 of Set 12 | coahuayana
# Processing Record 32 of Set 12 | puerto ayacucho
# Processing Record 33 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 12 | hervey bay
# Processing Record 35 of Set 12 | kalomo
# City not found. Skipping...
# Processing Record 36 of Set 12 | terni
# Processing Record 37 of Set 12 | ankazoabo
# Processing Record 38 of Set 12 | karla
# Processing Record 39 of Set 12 | bagrami
# Processing Record 40 of Set 12 | valenca
# Processing Record 41 of Set 12 | serik
# Processing Record 42 of Set 12 | san-pedro
# Processing Record 43 of Set 12 | gazanjyk
# Processing Record 44 of Set 12 | vila
# Processing Record 45 of Set 12 | prattville
# Processing Record 46 of Set 12 | beberibe
# Processing Record 47 of Set 12 | myre
# Processing Record 48 of Set 12 | one hundred mile house
# City not found. Skipping...
# Processing Record 49 of Set 12 | nishihara
# Processing Record 50 of Set 12 | vostok
# Processing Record 1 of Set 13 | gravdal
# Processing Record 2 of Set 13 | north bay
# Processing Record 3 of Set 13 | nurota
# Processing Record 4 of Set 13 | pasni
# Processing Record 5 of Set 13 | zhangye
# Processing Record 6 of Set 13 | ovalle
# Processing Record 7 of Set 13 | soyo
# Processing Record 8 of Set 13 | byron bay
# Processing Record 9 of Set 13 | leh
# Processing Record 10 of Set 13 | macapa
# Processing Record 11 of Set 13 | nuuk
# Processing Record 12 of Set 13 | yenangyaung
# Processing Record 13 of Set 13 | takhatgarh
# Processing Record 14 of Set 13 | manono
# Processing Record 15 of Set 13 | iralaya
# Processing Record 16 of Set 13 | witbank
# Processing Record 17 of Set 13 | sarany
# Processing Record 18 of Set 13 | krasnoarmeysk
# Processing Record 19 of Set 13 | alihe
# Processing Record 20 of Set 13 | amboasary
# Processing Record 21 of Set 13 | emerald
# Processing Record 22 of Set 13 | neka
# Processing Record 23 of Set 13 | saint-augustin
# Processing Record 24 of Set 13 | kulykivka
# Processing Record 25 of Set 13 | peniche
# Processing Record 26 of Set 13 | yithion
# City not found. Skipping...
# Processing Record 27 of Set 13 | la ronge
# Processing Record 28 of Set 13 | pokhara
# Processing Record 29 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 30 of Set 13 | sawakin
# Processing Record 31 of Set 13 | lhokseumawe
# Processing Record 32 of Set 13 | gizo
# Processing Record 33 of Set 13 | huainan
# Processing Record 34 of Set 13 | isla mujeres
# Processing Record 35 of Set 13 | kununurra
# Processing Record 36 of Set 13 | brokopondo
# Processing Record 37 of Set 13 | bongaree
# Processing Record 38 of Set 13 | ayodhya
# Processing Record 39 of Set 13 | valer
# Processing Record 40 of Set 13 | old bridge
# Processing Record 41 of Set 13 | vanavara
# Processing Record 42 of Set 13 | broadstairs
# Processing Record 43 of Set 13 | upata
# Processing Record 44 of Set 13 | coachella
# Processing Record 45 of Set 13 | lanzhou
# Processing Record 46 of Set 13 | riyadh
# Processing Record 47 of Set 13 | kokuy
# Processing Record 48 of Set 13 | ryazanskaya
# Processing Record 49 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 13 | high level
# Processing Record 1 of Set 14 | capreol
# Processing Record 2 of Set 14 | wamba
# Processing Record 3 of Set 14 | dingle
# Processing Record 4 of Set 14 | panguipulli
# Processing Record 5 of Set 14 | camenca
# Processing Record 6 of Set 14 | sur
# Processing Record 7 of Set 14 | ketchikan
# Processing Record 8 of Set 14 | mezhdurechensk
# Processing Record 9 of Set 14 | vung tau
# Processing Record 10 of Set 14 | tanda
# Processing Record 11 of Set 14 | pasco
# Processing Record 12 of Set 14 | pirapemas
# Processing Record 13 of Set 14 | burica
# City not found. Skipping...
# Processing Record 14 of Set 14 | mabaruma
# Processing Record 15 of Set 14 | shahr-e kord
# Processing Record 16 of Set 14 | clyde river
# Processing Record 17 of Set 14 | pyaozerskiy
# Processing Record 18 of Set 14 | sanming
# Processing Record 19 of Set 14 | palmer
# Processing Record 20 of Set 14 | otane
# Processing Record 21 of Set 14 | marrakesh
# Processing Record 22 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 14 | saint marys
# Processing Record 24 of Set 14 | pakenham
# Processing Record 25 of Set 14 | resende
# Processing Record 26 of Set 14 | krasnoselkup
# Processing Record 27 of Set 14 | guerrero negro
# Processing Record 28 of Set 14 | bemidji
# Processing Record 29 of Set 14 | tura
# Processing Record 30 of Set 14 | adelaide
# Processing Record 31 of Set 14 | lagos
# Processing Record 32 of Set 14 | san juan
# Processing Record 33 of Set 14 | sola
# Processing Record 34 of Set 14 | beyneu
# Processing Record 35 of Set 14 | jaguey grande
# Processing Record 36 of Set 14 | nueva gorgona
# Processing Record 37 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 38 of Set 14 | istok
# Processing Record 39 of Set 14 | valdivia
# Processing Record 40 of Set 14 | jalu
# Processing Record 41 of Set 14 | sao gabriel da cachoeira
# Processing Record 42 of Set 14 | sumbe
# Processing Record 43 of Set 14 | petropavlovskoye
# Processing Record 44 of Set 14 | umm kaddadah
# Processing Record 45 of Set 14 | le port
# Processing Record 46 of Set 14 | janauba
# Processing Record 47 of Set 14 | erdenet
# Processing Record 48 of Set 14 | padang
# Processing Record 49 of Set 14 | sept-iles
# Processing Record 50 of Set 14 | roald
# Processing Record 1 of Set 15 | salalah
# Processing Record 2 of Set 15 | stamsund
# City not found. Skipping...
# Processing Record 3 of Set 15 | kholtoson
# Processing Record 4 of Set 15 | nador
# Processing Record 5 of Set 15 | chatellerault
# Processing Record 6 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 7 of Set 15 | temuco
# Processing Record 8 of Set 15 | marienburg
# Processing Record 9 of Set 15 | xiongshi
# City not found. Skipping...
# Processing Record 10 of Set 15 | nanchang
# Processing Record 11 of Set 15 | redmond
# Processing Record 12 of Set 15 | owando
# Processing Record 13 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 15 | jawa
# Processing Record 15 of Set 15 | vila franca do campo
# Processing Record 16 of Set 15 | aksu
# Processing Record 17 of Set 15 | saint anthony
# Processing Record 18 of Set 15 | mozelos
# Processing Record 19 of Set 15 | sofiysk
# City not found. Skipping...
# Processing Record 20 of Set 15 | tatarani
# Processing Record 21 of Set 15 | coihaique
# Processing Record 22 of Set 15 | aklavik
# Processing Record 23 of Set 15 | esmeraldas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 624

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)# YOUR CODE HERE

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Rawson -43.3002  -65.1023     67.23        57         100
# 1     Cape Town -33.9258   18.4232     60.91        69           0
# 2          Hilo  19.7297 -155.0900     76.12        85          75
# 3      Chinsali -10.5414   32.0816     65.46        81         100
# 4         Muros  42.7762   -9.0603     60.10        94          91
# 5  Puerto Ayora  -0.7393  -90.3518     67.55        89          38
# 6     Jamestown  42.0970  -79.2353     56.79        27           0
# 7      Tateyama  34.9833  139.8667     69.73        55           0
# 8     Mahebourg -20.4081   57.7000     72.25        83          20
# 9    Bredasdorp -34.5322   20.0403     56.89        68          35
#
#    Wind Speed Country       Description
# 0       12.95      AR   overcast clouds
# 1       13.00      ZA         clear sky
# 2       12.66      US     moderate rain
# 3        5.66      ZM        light rain
# 4        7.61      ES   overcast clouds
# 5        5.01      EC  scattered clouds
# 6       12.66      US         clear sky
# 7       19.86      JP         clear sky
# 8        0.00      MU        few clouds
# 9        8.86      ZA  scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_cols = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity',  
            'Cloudiness', 'Wind Speed', 'Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_cols]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Rawson      AR -43.3002  -65.1023     67.23        57         100
# 1     Cape Town      ZA -33.9258   18.4232     60.91        69           0
# 2          Hilo      US  19.7297 -155.0900     76.12        85          75
# 3      Chinsali      ZM -10.5414   32.0816     65.46        81         100
# 4         Muros      ES  42.7762   -9.0603     60.10        94          91
# 5  Puerto Ayora      EC  -0.7393  -90.3518     67.55        89          38
# 6     Jamestown      US  42.0970  -79.2353     56.79        27           0
# 7      Tateyama      JP  34.9833  139.8667     69.73        55           0
# 8     Mahebourg      MU -20.4081   57.7000     72.25        83          20
# 9    Bredasdorp      ZA -34.5322   20.0403     56.89        68          35
#
#    Wind Speed       Description
# 0       12.95   overcast clouds
# 1       13.00         clear sky
# 2       12.66     moderate rain
# 3        5.66        light rain
# 4        7.61   overcast clouds
# 5        5.01  scattered clouds
# 6       12.66         clear sky
# 7       19.86         clear sky
# 8        0.00        few clouds
# 9        8.86  scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# Export the city_data DataFrame into a CSV file
output_file = "WeatherPy_Database.csv"
city_data_df.to_csv("./" + output_file, index_label="City_ID")
